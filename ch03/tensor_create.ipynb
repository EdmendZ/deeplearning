# %%
import torch
print(torch.__version__) # torch版本
print(torch.cuda.is_available())  # GPU 是否可用   windows
# Out:
# 2.12.0+cu132
# True

# %%
import torch

# 基础创建
x = torch.tensor([[1.0, 2.0], [3.0, 4.0]])

# 完整参数签名及在大模型开发中的常见用法
y = torch.tensor(
    data=[[1, 2], [3, 4]],
    dtype=torch.bfloat16,   # 大模型微调/推理极常用的数据类型，防止溢出
    device='cuda:0',        # 直接在显存中创建，避免 CPU->GPU 拷贝开销
    requires_grad=True      # 如果是需要优化的参数（如 LoRA 权重），设为 True
)

# %%
t1 = torch.tensor(10)
t2 = torch.tensor([10])
t3 = torch.tensor([[10]])

print(t1.item())
print(t2.item())
print(t3.item())
# Out:
# 10
# 10
# 10
