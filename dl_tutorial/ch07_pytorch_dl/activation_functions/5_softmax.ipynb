# %%
import torch

# %%
x = torch.randn(3, 5)
y = torch.softmax(x, dim=1)
print(x)
print(y)
# Out:
# tensor([[-1.2443,  0.2262,  0.5970, -1.3849,  1.0026],
#         [-0.2497,  2.5699,  0.7992,  0.1067, -0.2535],
#         [-0.7375,  0.9236,  0.8011,  0.8519,  1.1594]])
# tensor([[0.1864, 0.0745, 0.2898, 0.0675, 0.4074],
#         [0.5041, 0.7760, 0.3548, 0.3001, 0.1160],
#         [0.3095, 0.1496, 0.3554, 0.6323, 0.4766]])
