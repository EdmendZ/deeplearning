# %%
import torch
import torch.nn as nn

# %%
# 创建数据
x = torch.randn(3, 5)
t = torch.randn(3, 5)
print(x)
print(t)
# Out:
# tensor([[ 1.0466,  0.2742, -1.3339,  1.2839, -1.7390],
#         [ 0.6041, -1.0154,  0.0537, -0.6695,  0.6248],
#         [ 0.6505,  0.5832,  0.8220,  0.8834,  0.7126]])
# tensor([[-1.7946,  1.5516,  0.2881, -0.5380, -0.2120],
#         [ 1.0234,  1.4600,  0.1595, -0.0059, -0.3377],
#         [ 0.8803, -0.2503, -1.5293,  0.2594, -1.1782]])

# %%
# 计算损失
loss = nn.L1Loss()
print(loss(x, t))
# Out:
# tensor(1.3097)

# %%
loss = nn.MSELoss()
print(loss(x, t))
# Out:
# tensor(2.3939)

# %%
loss = nn.SmoothL1Loss()
print(loss(x, t))
# Out:
# tensor(0.8768)
